# %% [markdown]
# ## This problem is the study of data from Indian Premier League Cricket

# %%
#set your path to files you want to import
path = '/Users/clairehill/Documents/Udemy/Data_science/4-IPL_data_Analysis/'

#import your packages 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import your data files
matches = pd.read_csv(path+'matches.csv')
deliveries = pd.read_csv(path+'deliveries.csv')

# %%
#have a quick look at your data
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
#set a filter to only select the data with DA Warner at the batsman
filter = deliveries['batsman']=='DA Warner'
#apply this filter and make new dataframe with the selected data
df_warner = deliveries[filter]

# %%
df_warner
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 150283       636       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 150284       636       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 150288       636       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 150291       636       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 150292       636       1  Sunrisers Hyderabad  Royal Challengers Bangalore
#
# ...

# %%
#plit the dismissal kind data as a pie chart.

df_warner['dismissal_kind'].value_counts().plot.pie()

# %% [markdown]
# #### Above pie chart shows the highest dismissal was due to 'caught'

# %%
print('Total fours by DA W.') 
len(df_warner[df_warner['batsman_runs']==4])
# Out:
# Total fours by DA W.
# 401

# %%
print('Total 6s by DA W.') 
len(df_warner[df_warner['batsman_runs']==6])
# Out:
# Total 6s by DA W.
# 160

# %%
#define a funciton where you count the runs contribution
def count(df,runs):
    return len(df_warner[df_warner['batsman_runs']==runs])*runs

# %%
count(df_warner,1)
# Out:
# 997

# %%
count(df_warner,2)
# Out:
# 414

# %%
count(df_warner,3)
# Out:
# 39

# %%
count(df_warner,4)
# Out:
# 1604

# %%
count(df_warner,6)
# Out:
# 960

# %%
#to make a pie chart with these run contributions
slices=[count(df_warner,1), count(df_warner,2), count(df_warner,3), count(df_warner,4), count(df_warner,6)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-1b4fb55a97e7> in <module>
#       1 #to make a pie chart with these run contributions
# ----> 2 slices=[count(df_warner,1), count(df_warner,2), count(df_warner,3), count(df_warner,4), count(df_warner,6)]
#
# NameError: name 'df_warner' is not defined

# %%
labels=[1,2,3,4,6]

# %%
explode=[0,0,0,0,0.1]
plt.pie(slices, labels=labels, autopct='%1.1f%%', explode=explode)
plt.title("DA Warner total runs contribution")
plt.tight_layout()
plt.show()

# %%
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
deliveries['bowling_team'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiant', 'Mumbai Indians',
#        'Kolkata Knight Riders', 'Gujarat Lions', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Deccan Chargers', 'Kochi Tuskers Kerala', 'Pune Warriors',
#        'Rising Pune Supergiants'], dtype=object)

# %%
#rename the team names with abbreviations by making dictionary with abbreviations and mapping them to the dataframe.
Teams={
    'Royal Challengers Bangalore':'RCB', 
    'Sunrisers Hyderabad':'SRH',
       'Rising Pune Supergiant':'RPS',
    'Mumbai Indians':'MI',
       'Kolkata Knight Riders':'KKR', 
    'Gujarat Lions':'GL',
    'Kings XI Punjab':'KXIP',
       'Delhi Daredevils':'DD',
    'Chennai Super Kings':'CSK',
    'Rajasthan Royals':'RR',
       'Deccan Chargers':'DC',
    'Kochi Tuskers Kerala':'KTK',
    'Pune Warriors':'PW',
       'Rising Pune Supergiants':'RPS'
}

# %%
deliveries['batting_team']=deliveries['batting_team'].map(Teams)
deliveries['bowling_team']=deliveries['bowling_team'].map(Teams)
deliveries
# Out:
#         match_id  inning batting_team bowling_team  over  ball        batsman  \
# 0              1       1          SRH          RCB     1     1      DA Warner
# 1              1       1          SRH          RCB     1     2      DA Warner
# 2              1       1          SRH          RCB     1     3      DA Warner
# 3              1       1          SRH          RCB     1     4      DA Warner
# 4              1       1          SRH          RCB     1     5      DA Warner
# ...          ...     ...          ...          ...   ...   ...            ...
# 150455       636       2          RCB          SRH    20     2    Sachin Baby
# 150456       636       2          RCB          SRH    20     3    Sachin Baby
# 150457       636       2          RCB          SRH    20     4  Iqbal Abdulla
# 150458       636       2          RCB          SRH    20     5    Sachin Baby
# 150459       636       2          RCB          SRH    20     6  Iqbal Abdulla
#
# ...

# %%
#score distribtution per team by innings
runs = deliveries.groupby(['match_id','inning','batting_team'])['total_runs'].sum().reset_index()
runs.drop('match_id', axis=1, inplace=True)
runs
# Out:
#       inning batting_team  total_runs
# 0          1          SRH         207
# 1          2          RCB         172
# 2          1           MI         184
# 3          2          RPS         187
# 4          1           GL         183
# ...      ...          ...         ...
# 1279       2          KKR         140
# 1280       1           GL         162
# 1281       2          SRH         163
# 1282       1          SRH         208
# 1283       2          RCB         200
#
# [1284 rows x 3 columns]

# %%
inning1=runs[runs['inning']==1]
inning2=runs[runs['inning']==2]

# %%
#plotting inning 1
sns.boxplot(x='batting_team',y='total_runs',data=inning1)

# %% [markdown]
# CSK & RCB seems best

# %%
#plotting inning 2
sns.boxplot(x='batting_team',y='total_runs',data=inning2)

# %% [markdown]
# #### According ot the above graphs, batting by CSK & RCB seems best

# %%
high_scores=deliveries.groupby(['match_id', 'inning','batting_team','bowling_team'])['total_runs'].sum().reset_index() 
high_scores
# Out:
#       match_id  inning batting_team bowling_team  total_runs
# 0            1       1          SRH          RCB         207
# 1            1       2          RCB          SRH         172
# 2            2       1           MI          RPS         184
# 3            2       2          RPS           MI         187
# 4            3       1           GL          KKR         183
# ...        ...     ...          ...          ...         ...
# 1279       634       2          KKR          SRH         140
# 1280       635       1           GL          SRH         162
# 1281       635       2          SRH           GL         163
# 1282       636       1          SRH          RCB         208
# 1283       636       2          RCB          SRH         200
#
# [1284 rows x 5 columns]

# %%
#how many times teams scores more than 200
score_200=high_scores[high_scores['total_runs']>=200]
score_200
# Out:
#       match_id  inning batting_team bowling_team  total_runs
# 0            1       1          SRH          RCB         207
# 16           9       1           DD          RPS         205
# 38          20       1          RCB           GL         213
# 62          32       1          SRH         KXIP         207
# 72          36       1          SRH          KKR         209
# ...        ...     ...          ...          ...         ...
# 1250       620       1          RCB           GL         248
# 1256       623       1           MI           DD         206
# 1262       626       1          RCB         KXIP         211
# 1282       636       1          SRH          RCB         208
# 1283       636       2          RCB          SRH         200
#
# [67 rows x 5 columns]

# %%
plt.figure(figsize=(10,6))
sns.countplot(score_200['batting_team'])

# %% [markdown]
# #### The above graph shows the number of times a team scored more than 200 runs

# %%
sns.countplot(score_200['bowling_team'])

# %% [markdown]
# #### The above graph shows the number of times a bowling team conceeded more than 200 runs

# %%
#Batsman Comparison
balls=deliveries.groupby(['batsman'])['ball'].count().reset_index()
balls
# Out:
#             batsman  ball
# 0    A Ashish Reddy   196
# 1        A Chandila     7
# 2          A Chopra    75
# 3       A Choudhary    20
# 4        A Flintoff    57
# ..              ...   ...
# 456     YV Takawale   183
# 457   Yashpal Singh    67
# 458     Younis Khan     7
# 459    Yuvraj Singh  2050
# 460          Z Khan   141
#
# [461 rows x 2 columns]

# %%
runs=deliveries.groupby(['batsman'])['batsman_runs'].sum().reset_index()
runs.columns=['batsman','runs']
runs
# Out:
#             batsman  runs
# 0    A Ashish Reddy   280
# 1        A Chandila     4
# 2          A Chopra    53
# 3       A Choudhary    25
# 4        A Flintoff    62
# ..              ...   ...
# 456     YV Takawale   192
# 457   Yashpal Singh    47
# 458     Younis Khan     3
# 459    Yuvraj Singh  2591
# 460          Z Khan   117
#
# [461 rows x 2 columns]

# %%
four = deliveries[deliveries['batsman_runs']==4]

# %%
four
# Out:
#         match_id  inning batting_team bowling_team  over  ball        batsman  \
# 2              1       1          SRH          RCB     1     3      DA Warner
# 8              1       1          SRH          RCB     2     2      DA Warner
# 13             1       1          SRH          RCB     2     7   MC Henriques
# 30             1       1          SRH          RCB     5     5   MC Henriques
# 32             1       1          SRH          RCB     6     1       S Dhawan
# ...          ...     ...          ...          ...   ...   ...            ...
# 150403       636       2          RCB          SRH    11     4        V Kohli
# 150407       636       2          RCB          SRH    12     2        V Kohli
# 150418       636       2          RCB          SRH    14     1       KL Rahul
# 150447       636       2          RCB          SRH    18     6    Sachin Baby
# 150459       636       2          RCB          SRH    20     6  Iqbal Abdulla
#
# ...

# %%
four.groupby('batsman')['batsman_runs'].count().reset_index()
runs_4=four.groupby('batsman')['batsman_runs'].count().reset_index()
runs_4.columns=['batsman','4s']
runs_4
# Out:
#             batsman   4s
# 0    A Ashish Reddy   16
# 1          A Chopra    7
# 2       A Choudhary    1
# 3        A Flintoff    5
# 4          A Kumble    3
# ..              ...  ...
# 363       YK Pathan  240
# 364     YV Takawale   26
# 365   Yashpal Singh    5
# 366    Yuvraj Singh  205
# 367          Z Khan   11
#
# [368 rows x 2 columns]

# %%
runs_6=deliveries.groupby('batsman')['batsman_runs'].agg(lambda x: (x==6).sum()).reset_index()

runs_6.columns=['batsman','6s']

runs_6
# Out:
#             batsman   6s
# 0    A Ashish Reddy   15
# 1        A Chandila    0
# 2          A Chopra    0
# 3       A Choudhary    1
# 4        A Flintoff    2
# ..              ...  ...
# 456     YV Takawale    3
# 457   Yashpal Singh    0
# 458     Younis Khan    0
# 459    Yuvraj Singh  141
# 460          Z Khan    2
#
# [461 rows x 2 columns]

# %%
#iloc is idex location - we just need the second column from each df
#axis=1 to concat vertically
player=pd.concat([runs,balls.iloc[:,1],runs_4.iloc[:,1],runs_6.iloc[:,1]],axis=1)
player
# Out:
#             batsman  runs  ball    4s   6s
# 0    A Ashish Reddy   280   196  16.0   15
# 1        A Chandila     4     7   7.0    0
# 2          A Chopra    53    75   1.0    0
# 3       A Choudhary    25    20   5.0    1
# 4        A Flintoff    62    57   3.0    2
# ..              ...   ...   ...   ...  ...
# 456     YV Takawale   192   183   NaN    3
# 457   Yashpal Singh    47    67   NaN    0
# 458     Younis Khan     3     7   NaN    0
# 459    Yuvraj Singh  2591  2050   NaN  141
# 460          Z Khan   117   141   NaN    2
#
# [461 rows x 5 columns]

# %%
player.fillna(0, inplace=True)
player
# Out:
#             batsman  runs  ball    4s   6s
# 0    A Ashish Reddy   280   196  16.0   15
# 1        A Chandila     4     7   7.0    0
# 2          A Chopra    53    75   1.0    0
# 3       A Choudhary    25    20   5.0    1
# 4        A Flintoff    62    57   3.0    2
# ..              ...   ...   ...   ...  ...
# 456     YV Takawale   192   183   0.0    3
# 457   Yashpal Singh    47    67   0.0    0
# 458     Younis Khan     3     7   0.0    0
# 459    Yuvraj Singh  2591  2050   0.0  141
# 460          Z Khan   117   141   0.0    2
#
# [461 rows x 5 columns]

# %%
player['strike_rate']=player['runs']/player['ball']
player.head()
# Out:
#           batsman  runs  ball    4s  6s  strike_rate
# 0  A Ashish Reddy   280   196  16.0  15     1.428571
# 1      A Chandila     4     7   7.0   0     0.571429
# 2        A Chopra    53    75   1.0   0     0.706667
# 3     A Choudhary    25    20   5.0   1     1.250000
# 4      A Flintoff    62    57   3.0   2     1.087719

# %%
player.isnull().values.any()
# Out:
# False

# %%
deliveries.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
grp=deliveries.groupby(['match_id','batsman','batting_team'])['batsman_runs'].sum().reset_index()
grp
# Out:
#       match_id       batsman batting_team  batsman_runs
# 0            1   A Choudhary          RCB             6
# 1            1   BCJ Cutting          SRH            16
# 2            1      CH Gayle          RCB            32
# 3            1     DA Warner          SRH            14
# 4            1      DJ Hooda          SRH            16
# ...        ...           ...          ...           ...
# 9510       636     SR Watson          RCB            11
# 9511       636     STR Binny          RCB             9
# 9512       636   Sachin Baby          RCB            18
# 9513       636       V Kohli          RCB            54
# 9514       636  Yuvraj Singh          SRH            38
#
# [9515 rows x 4 columns]

# %%
max=grp.groupby(['batsman'])['batsman_runs'].max().reset_index()
max.columns=['batsman','max_runs']
max
# Out:
#             batsman  max_runs
# 0    A Ashish Reddy        36
# 1        A Chandila         4
# 2          A Chopra        24
# 3       A Choudhary        15
# 4        A Flintoff        24
# ..              ...       ...
# 456     YV Takawale        45
# 457   Yashpal Singh        20
# 458     Younis Khan         3
# 459    Yuvraj Singh        83
# 460          Z Khan        23
#
# [461 rows x 2 columns]

# %%
player2=pd.concat([player,max.iloc[:,1:3]],axis=1)
player2
# Out:
#             batsman  runs  ball    4s   6s  strike_rate  max_runs
# 0    A Ashish Reddy   280   196  16.0   15     1.428571        36
# 1        A Chandila     4     7   7.0    0     0.571429         4
# 2          A Chopra    53    75   1.0    0     0.706667        24
# 3       A Choudhary    25    20   5.0    1     1.250000        15
# 4        A Flintoff    62    57   3.0    2     1.087719        24
# ..              ...   ...   ...   ...  ...          ...       ...
# 456     YV Takawale   192   183   0.0    3     1.049180        45
# 457   Yashpal Singh    47    67   0.0    0     0.701493        20
# 458     Younis Khan     3     7   0.0    0     0.428571         3
# 459    Yuvraj Singh  2591  2050   0.0  141     1.263902        83
# 460          Z Khan   117   141   0.0    2     0.829787        23
#
# [461 rows x 7 columns]

# %%
#Top 10 Batsman
max_runs=deliveries.groupby(['batsman'])['batsman_runs'].sum()
max_runs.sort_values(ascending=False)[:10].plot.bar()

# %% [markdown]
# #### SK Raina has highest total runs during all seasons.
# #### Virat Kohliis was second place

# %%
deliveries.groupby(["match_id","batsman",'batting_team'])["batsman_runs"].sum().reset_index().sort_values(by='batsman_runs', ascending=False).head(10)
# Out:
#       match_id         batsman batting_team  batsman_runs
# 6200       411        CH Gayle          RCB           175
# 900         60     BB McCullum          KKR           158
# 8426       562  AB de Villiers          RCB           133
# 9257       620  AB de Villiers          RCB           129
# 5585       372        CH Gayle          RCB           128
# 3135       206         M Vijay          CSK           127
# 529         36       DA Warner          SRH           126
# 7752       516        V Sehwag         KXIP           122
# 3686       243     PC Valthaty         KXIP           120
# 4223       279        V Sehwag           DD           119

# %% [markdown]
# #### Gayle is top. Many RCB players on the top scores list.

# %%
deliveries['dismissal_kind'].unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'caught and bowled',
#        'stumped', 'retired hurt', 'hit wicket', 'obstructing the field'],
#       dtype=object)

# %%
#Removing the dismissals not credited to the bowler
dismissal_kinds = ['caught', 'bowled', 'lbw', 'caught and bowled',
       'stumped', 'hit wicket']

# %%
hwt=deliveries[deliveries["dismissal_kind"].isin(dismissal_kinds)]
hwt.head()
# Out:
#      match_id  inning batting_team bowling_team  over  ball        batsman  \
# 11          1       1          SRH          RCB     2     5      DA Warner
# 64          1       1          SRH          RCB    11     3       S Dhawan
# 94          1       1          SRH          RCB    16     2   MC Henriques
# 116         1       1          SRH          RCB    19     4   Yuvraj Singh
# 160         1       2          RCB          SRH     6     4  Mandeep Singh
#
#       non_striker       bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 11       S Dhawan  A Choudhary              0  ...         0            0
# 64   MC Henriques    STR Binny              0  ...         0            0
# 94   Yuvraj Singh    YS Chahal              0  ...         0            0
# 116      DJ Hooda     TS Mills              0  ...         0            0
# 160      CH Gayle  Rashid Khan              0  ...         0            0
#
# ...

# %%
hwt['bowler'].value_counts()[:10].plot.bar()

# %% [markdown]
# #### Lasith Malinga has the highest dismissal count

# %% [markdown]
# ## Some Basic Match Analysis

# %%
matches.head()
# Out:
#    id  season       city      date                        team1  \
# 0   1    2017  Hyderabad  4/5/2017          Sunrisers Hyderabad
# 1   2    2017       Pune  4/6/2017               Mumbai Indians
# 2   3    2017     Rajkot  4/7/2017                Gujarat Lions
# 3   4    2017     Indore  4/8/2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  4/8/2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# ...

# %%
matches.isnull().sum()
# Out:
# id                 0
# season             0
# city               7
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             3
# win_by_runs        0
# win_by_wickets     0
# player_of_match    3
# venue              0
# umpire1            1
# umpire2            1
# dtype: int64

# %%
matches.shape
# Out:
# (636, 17)

# %%
matches.drop(['umpire3'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-1eb750794f81> in <module>
# ----> 1 matches.drop(['umpire3'],axis=1,inplace=True)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
# ...

# %%
matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
matches['team1']=matches['team1'].map(Teams)
matches['team2']=matches['team2'].map(Teams)

# %%
matches.head()
# Out:
#    id  season       city      date team1 team2                  toss_winner  \
# 0   1    2017  Hyderabad  4/5/2017   SRH   RCB  Royal Challengers Bangalore
# 1   2    2017       Pune  4/6/2017    MI   RPS       Rising Pune Supergiant
# 2   3    2017     Rajkot  4/7/2017    GL   KKR        Kolkata Knight Riders
# 3   4    2017     Indore  4/8/2017   RPS  KXIP              Kings XI Punjab
# 4   5    2017  Bangalore  4/8/2017   RCB    DD  Royal Challengers Bangalore
#
#   toss_decision  result  dl_applied                       winner  win_by_runs  \
# 0         field  normal           0          Sunrisers Hyderabad           35
# 1         field  normal           0       Rising Pune Supergiant            0
# 2         field  normal           0        Kolkata Knight Riders            0
# 3         field  normal           0              Kings XI Punjab            0
# 4           bat  normal           0  Royal Challengers Bangalore           15
#
# ...

# %%
print('Number of mathces played:', matches.shape[0])
# Out:
# Number of mathces played: 636

# %%
print('Number of locations for matches:', len(matches['city'].unique()))
# Out:
# Number of locations for matches: 31

# %%
print('Number of teams:', len(matches['team1'].unique()))
# Out:
# Number of teams: 13

# %%
print(matches['player_of_match'].value_counts())
# Out:
# CH Gayle             18
# YK Pathan            16
# DA Warner            15
# AB de Villiers       15
# SK Raina             14
#                      ..
# RP Singh              1
# TA Boult              1
# Q de Kock             1
# J Botha               1
# Mustafizur Rahman     1
# Name: player_of_match, Length: 201, dtype: int64

# %%
matches[matches['win_by_runs']==matches['win_by_runs'].max()]
# Out:
#     id  season   city      date team1 team2       toss_winner toss_decision  \
# 43  44    2017  Delhi  5/6/2017    MI    DD  Delhi Daredevils         field
#
#     result  dl_applied          winner  win_by_runs  win_by_wickets  \
# 43  normal           0  Mumbai Indians          146               0
#
#    player_of_match             venue      umpire1    umpire2
# 43     LMP Simmons  Feroz Shah Kotla  Nitin Menon  CK Nandan

# %% [markdown]
# #### MI beat DD with biggest difference win by runs

# %%
matches[matches['win_by_wickets']==matches['win_by_wickets'].max()]
# Out:
#       id  season        city       date team1 team2  \
# 2      3    2017      Rajkot   4/7/2017    GL   KKR
# 34    35    2017  Chandigarh  4/30/2017    DD  KXIP
# 71    72    2008      Mumbai  4/27/2008    MI    DC
# 119  120    2009   Cape Town  4/19/2009  KXIP    DD
# 183  184    2010   Bangalore  3/18/2010    RR   RCB
# 298  299    2011      Mumbai  5/20/2011    MI    RR
# 376  377    2012      Jaipur  5/20/2012    RR    MI
# 390  391    2013  Chandigarh  4/10/2013  KXIP   CSK
# 542  543    2015       Delhi  4/26/2015    DD   RCB
# 590  591    2016      Rajkot  4/21/2016    GL   SRH
#
#                      toss_winner toss_decision  result  dl_applied  \
# 2          Kolkata Knight Riders         field  normal           0
# 34               Kings XI Punjab         field  normal           0
# 71               Deccan Chargers         field  normal           0
# 119             Delhi Daredevils         field  normal           1
# ...

# %% [markdown]
# #### The teams above had the biggest win by wickets

# %%
#Toss Decisions across Season
sns.countplot(x='season',hue='toss_decision',data=matches)

# %% [markdown]
# #### The probablity that toss winners opt for batting is high. In 2016, the majority of toss winners opted for fielding

# %%
#Maximum Toss Winners
matches['toss_winner'].value_counts().plot(kind='bar')

# %% [markdown]
# #### MI win the most toss decisions

# %%
#to determine total Matches vs Wins for Team
teams=(matches['team1'].value_counts()+matches['team2'].value_counts()).reset_index()
teams.columns=['team_name','Matches_played']
teams
# Out:
#    team_name  Matches_played
# 0        CSK             131
# 1         DC              75
# 2         DD             147
# 3         GL              30
# 4        KKR             148
# 5        KTK              14
# 6       KXIP             148
# 7         MI             157
# 8         PW              46
# 9        RCB             152
# 10       RPS              30
# 11        RR             118
# 12       SRH              76

# %%
matches['winner']=matches['winner'].map(Teams)

# %%
wins = matches['winner'].value_counts().reset_index()
wins.columns=['team_name','wins']
wins
# Out:
#    team_name  wins
# 0         MI    92
# 1        CSK    79
# 2        KKR    77
# 3        RCB    73
# 4       KXIP    70
# 5         RR    63
# 6         DD    62
# 7        SRH    42
# 8         DC    29
# 9        RPS    15
# 10        GL    13
# 11        PW    12
# 12       KTK     6

# %%
player=teams.merge(wins,left_on='team_name',right_on='team_name',how='inner')

# %%
player.columns=['team','matches_played','wins']
player
# Out:
#     team  matches_played  wins
# 0    CSK             131    79
# 1     DC              75    29
# 2     DD             147    62
# 3     GL              30    13
# 4    KKR             148    77
# 5    KTK              14     6
# 6   KXIP             148    70
# 7     MI             157    92
# 8     PW              46    12
# 9    RCB             152    73
# 10   RPS              30    15
# 11    RR             118    63
# 12   SRH              76    42

# %%
player['%win']=(player['wins']/player['matches_played'])*100
player
# Out:
#     team  matches_played  wins       %win
# 0    CSK             131    79  60.305344
# 1     DC              75    29  38.666667
# 2     DD             147    62  42.176871
# 3     GL              30    13  43.333333
# 4    KKR             148    77  52.027027
# 5    KTK              14     6  42.857143
# 6   KXIP             148    70  47.297297
# 7     MI             157    92  58.598726
# 8     PW              46    12  26.086957
# 9    RCB             152    73  48.026316
# 10   RPS              30    15  50.000000
# 11    RR             118    63  53.389831
# 12   SRH              76    42  55.263158

# %%
import plotly.offline as py
import plotly.graph_objs as go

# %%
trace1 = go.Bar(
    x=player['team'],
    y=player['matches_played'],
    name='Total Matches'
)
trace2 = go.Bar(
    x=player.team,
    y=player['wins'],
    name='Matches Won'
)

# %%
data = [trace1, trace2]
py.iplot(data)
# Out:
# <div>                            <div id="3537cde2-d968-4da2-9738-95c7782d79a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3537cde2-d968-4da2-9738-95c7782d79a2")) {                    Plotly.newPlot(                        "3537cde2-d968-4da2-9738-95c7782d79a2",                        [{"name": "Total Matches", "type": "bar", "x": ["CSK", "DC", "DD", "GL", "KKR", "KTK", "KXIP", "MI", "PW", "RCB", "RPS", "RR", "SRH"], "y": [131, 75, 147, 30, 148, 14, 148, 157, 46, 152, 30, 118, 76]}, {"name": "Matches Won", "type": "bar", "x": ["CSK", "DC", "DD", "GL", "KKR", "KTK", "KXIP", "MI", "PW", "RCB", "RPS", "RR", "SRH"], "y": [79, 29, 62, 13, 77, 6, 70, 92, 12, 73, 15, 63, 42]}],                        {"template": {"data": {"bar": [{"error_x": {"color"
# ...

# %%
#Matches played across each seasosn
countplot(matches['season'])

# %%
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
season=matches[['id','season']].merge(deliveries, left_on = 'id', right_on = 'match_id', how = 'left').drop('id', axis = 1)
season
# Out:
#         season  match_id  inning                 batting_team  \
# 0         2017         1       1          Sunrisers Hyderabad
# 1         2017         1       1          Sunrisers Hyderabad
# 2         2017         1       1          Sunrisers Hyderabad
# 3         2017         1       1          Sunrisers Hyderabad
# 4         2017         1       1          Sunrisers Hyderabad
# ...        ...       ...     ...                          ...
# 150455    2016       636       2  Royal Challengers Bangalore
# 150456    2016       636       2  Royal Challengers Bangalore
# 150457    2016       636       2  Royal Challengers Bangalore
# 150458    2016       636       2  Royal Challengers Bangalore
# 150459    2016       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# ...

# %%
#Runs Across the Seasons
season=season.groupby(['season'])['total_runs'].sum().reset_index()
season.set_index('season').plot()
plt.title('Total Runs Across the Seasons')
plt.show()

# %%
avg_runs=matches.groupby(['season'])['id'].count().reset_index().rename(columns={'id':'matches'})
avg_runs
# Out:
#    season  matches
# 0    2008       58
# 1    2009       57
# 2    2010       60
# 3    2011       73
# 4    2012       74
# 5    2013       76
# 6    2014       60
# 7    2015       59
# 8    2016       60
# 9    2017       59

# %%
season
# Out:
#    season  total_runs
# 0    2008       17937
# 1    2009       16353
# 2    2010       18883
# 3    2011       21154
# 4    2012       22453
# 5    2013       22602
# 6    2014       18931
# 7    2015       18353
# 8    2016       18862
# 9    2017       18786

# %%
final=pd.concat([avg_runs,season.iloc[:,1]],axis=1)
final
# Out:
#    season  matches  total_runs
# 0    2008       58       17937
# 1    2009       57       16353
# 2    2010       60       18883
# 3    2011       73       21154
# 4    2012       74       22453
# 5    2013       76       22602
# 6    2014       60       18931
# 7    2015       59       18353
# 8    2016       60       18862
# 9    2017       59       18786

# %%
final['per_match_runs']=final['total_runs']/final['matches']
final.set_index('season',inplace=True)

# %%
final
# Out:
#         matches  total_runs  per_match_runs
# season
# 2008         58       17937      309.258621
# 2009         57       16353      286.894737
# 2010         60       18883      314.716667
# 2011         73       21154      289.780822
# 2012         74       22453      303.418919
# 2013         76       22602      297.394737
# 2014         60       18931      315.516667
# 2015         59       18353      311.067797
# 2016         60       18862      314.366667
# 2017         59       18786      318.406780

# %%
final['per_match_runs'].plot()

# %%
#most lucky grounds for teams
def lucky(df,team_name):
    return matches[matches['winner']==team_name]['venue'].value_counts().nlargest(5)

# %%
lucky(matches,'MI').plot(kind='bar')

# %%
def comparison(team1,team2):
    compare=matches[((matches['team1']==team1)|(matches['team2']==team1))&((matches['team1']==team2)|(matches['team2']==team2))]
    sns.countplot(x='season', hue='winner',data=compare)

# %%
comparison('MI','CSK')

# %% [markdown]
# ####  MI and CSK have played against each other in more than 2 matches. MI dominates
